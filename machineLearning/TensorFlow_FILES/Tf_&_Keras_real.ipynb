# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('DATA/kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
#Checking for empty values in the dataset

# %%
df.isnull().sum() #No missing data
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
#Data visulization

# %%
#disturbution plot
plt.figure(figsize=(10,7))
sns.distplot(df['price'])

# %%
sns.countplot(df['bedrooms'])

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.701917
# grade            0.667951
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# view             0.397370
# sqft_basement    0.323799
# bedrooms         0.308787
# lat              0.306692
# waterfront       0.266398
# floors           0.256804
# yr_renovated     0.126424
# sqft_lot         0.089876
# sqft_lot15       0.082845
# yr_built         0.053953
# condition        0.036056
# long             0.022036
# id              -0.016772
# zipcode         -0.053402
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x=df['price'], y=df['sqft_living'], data=df)

# %%
df['grade'].describe()
# Out:
# count    21597.000000
# mean         7.657915
# std          1.173200
# min          3.000000
# 25%          7.000000
# 50%          7.000000
# 75%          8.000000
# max         13.000000
# Name: grade, dtype: float64

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='bedrooms', y='price', data=df)

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x='price', y='long', data =df)

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x='price', y='lat', data =df)

# %%
#From this plots we can see that there are some places that more 
# expensive than the others based on geographical location

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x = 'long', y='lat', data=df, hue='price')

# %%
df.sort_values('price', ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*0.01
# Out:
# 215.97

# %%
non_top_1_perc = df.sort_values('price', ascending=False).iloc[216:]

# %%
sns.distplot(non_top_1_perc['price'])

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x = 'long', y='lat', data=non_top_1_perc, hue='price',
               edgecolor = None, alpha=0.2, palette='RdYlGn')

# %%
sns.boxplot(x='waterfront', y='price', data=df)

# %%
#Feature enginerring process

# %%
df = df.drop('id', axis=1)

# %%
#Converting the date string to a date time object
df['date'] = pd.to_datetime(df['date'])

# %%
df['date'].head()
# Out:
# 0   2014-10-13
# 1   2014-12-09
# 2   2015-02-25
# 3   2014-12-09
# 4   2015-02-18
# Name: date, dtype: datetime64[ns]

# %%
#Extracting the year
df['year'] = df['date'].apply(lambda date: date.year)

# %%
df['month'] = df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
# lets see if there a price difference according to the month or year

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='month', y='price', data=df)

# %%
df.groupby('year').mean()['price'].plot()

# %%
df = df.drop('date', axis=1)

# %%
df = df.drop('zipcode', axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
# When we see the year renoveted colunme we can see that
# as the year increases the value might be higher
df['yr_renovated'] = df['yr_renovated'].apply(lambda year: 1 if year > 0 else 0 )

# %%
df['sqft_basement'].value_counts()
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('price', axis=1).values #.values will return the numpy array format

# %%
y = df['price'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

# %%
#We usally scale our neurons according to 
# the incoming features
X_train.shape
# Out:
# (15117, 19)

# %%
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))


model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')#adam optimizer

# %%
model.fit(x=X_train, y=y_train, 
          validation_data= (X_test, y_test),
         batch_size=128, # smaller batch set => !overfitting
          epochs =400,
         )
# Out:
# Epoch 1/400
# 119/119 [==============================] - 1s 5ms/step - loss: 430237777920.0000 - val_loss: 418898083840.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 4ms/step - loss: 428685590528.0000 - val_loss: 413417668608.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 3ms/step - loss: 406866952192.0000 - val_loss: 364679102464.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 4ms/step - loss: 310133063680.0000 - val_loss: 219010220032.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 4ms/step - loss: 154914816000.0000 - val_loss: 102769926144.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 3ms/step - loss: 100308246528.0000 - val_loss: 94689992704.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 4ms/step - loss: 96953262080.0000 - val_loss: 93055369216.0000
# Epoch 8/400
# ...

# %%
#Model evaluation and predictions

# %%
loss_df = pd.DataFrame(model.history.history)

# %%
loss_df.plot()

# %%
#model evaluation

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error, explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
print(mean_squared_error(y_test, predictions)**0.5)
print(mean_absolute_error(y_test, predictions))
print(explained_variance_score(y_test, predictions))
# Out:
# 162108.50381971986
# 100520.77719786845
# 0.801883164710382

# %%
plt.figure(figsize=(12,6))
plt.scatter(y_test, predictions)
plt.plot(y_test, y_test, 'r')

# %%
single_house = df.drop('price', axis=1).iloc[0]

# %%
single_house.values.reshape(-1,19)
# Out:
# array([[ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#          1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#          7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#          0.00000e+00,  4.75112e+01, -1.22257e+02,  1.34000e+03,
#          5.65000e+03,  2.01400e+03,  1.00000e+01]])

# %%
single_house = scaler.transform(single_house.values.reshape(-1,19))

# %%
model.predict(single_house)
# Out:
# array([[273398.84]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10
